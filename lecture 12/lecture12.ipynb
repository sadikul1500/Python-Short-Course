# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 12) 
pd.set_option('display.max_rows', 15)

# %%
df = pd.read_csv("diamonds.csv") # 'https://github.com/Md-Siam07/dataset/blob/main/diamonds.csv'
# df = pd.read_csv('https://raw.githubusercontent.com/Md-Siam07/dataset/main/diamonds.csv')

# %%
df.head()
# Out:
#    rownames  carat      cut color clarity  depth  table  price     x     y  \
# 0         1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1         2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2         3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3         4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4         5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %% [markdown]
# **Read from web source**

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df_list = pd.read_html("https://www.w3schools.com/html/html_tables.asp")

print(df_list)
print(type(df_list)) # This will show that df_list is a list of DataFrames
# Out:
# [                        Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy,           Tag                                        Description
# 0     <table>                                    Defines a table
# 1        <th>                   Defines a header cell in a table
# 2        <tr>                           Defines a row in a table
# 3        <td>                          Defines a cell in a table
# 4   <caption>                            Defines a table caption
# 5  <colgroup>  Specifies a group of one or more columns in a ...
# 6       <col>  Specifies column properties for each column wi...
# ...

# %%
df_list[1]
# Out:
#           Tag                                        Description
# 0     <table>                                    Defines a table
# 1        <th>                   Defines a header cell in a table
# 2        <tr>                           Defines a row in a table
# 3        <td>                          Defines a cell in a table
# 4   <caption>                            Defines a table caption
# 5  <colgroup>  Specifies a group of one or more columns in a ...
# 6       <col>  Specifies column properties for each column wi...
# 7     <thead>               Groups the header content in a table
# 8     <tbody>                 Groups the body content in a table
# 9     <tfoot>               Groups the footer content in a table

# %%
df.head()
# Out:
#    rownames  carat      cut color clarity  depth  table  price     x     y  \
# 0         1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1         2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2         3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3         4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4         5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
# Display the first 8 rows
df.head(8)
# Out:
#    rownames  carat        cut color clarity  depth  table  price     x     y  \
# 0         1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1         2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2         3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3         4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4         5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# 5         6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96
# 6         7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98
# 7         8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75
# 5  2.48
# 6  2.47
# 7  2.53

# %%
# Display the last 5 rows (default)
df.tail()
# Out:
#        rownames  carat        cut color clarity  depth  table  price     x  \
# 53935     53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936     53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937     53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938     53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939     53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
# Display the last 12 rows
df.tail(12)
# Out:
#        rownames  carat        cut color clarity  depth  table  price     x  \
# 53928     53929   0.79    Premium     E     SI2   61.4   58.0   2756  6.03
# 53929     53930   0.71      Ideal     G     VS1   61.4   56.0   2756  5.76
# 53930     53931   0.71    Premium     E     SI1   60.5   55.0   2756  5.79
# 53931     53932   0.71    Premium     F     SI1   59.8   62.0   2756  5.74
# 53932     53933   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71
# 53933     53934   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69
# 53934     53935   0.72    Premium     D     SI1   62.7   59.0   2757  5.69
# 53935     53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936     53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937     53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938     53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# ...

# %%
df.shape
# Out:
# (53940, 11)

# %%
print(df.columns)
# Out:
# Index(['rownames', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='str')

# %%
listed_columns = df.columns.to_list()
listed_columns
# Out:
# ['rownames',
#  'carat',
#  'cut',
#  'color',
#  'clarity',
#  'depth',
#  'table',
#  'price',
#  'x',
#  'y',
#  'z']

# %%
# Get data types for each column
df.dtypes
# Out:
# rownames      int64
# carat       float64
# cut             str
# color           str
# clarity         str
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  53940 non-null  int64
#  1   carat     53940 non-null  float64
#  2   cut       53940 non-null  str
#  3   color     53940 non-null  str
#  4   clarity   53940 non-null  str
#  5   depth     53940 non-null  float64
#  6   table     53940 non-null  float64
#  7   price     53940 non-null  int64
#  8   x         53940 non-null  float64
#  9   y         53940 non-null  float64
#  10  z         53940 non-null  float64
# dtypes: float64(6), int64(2), str(3)
# memory usage: 4.5 MB

# %%
df.describe()
# Out:
#            rownames         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
# Include all columns (including non-numeric)
df.describe(include='all')
# Out:
#             rownames         carat    cut  color clarity         depth  \
# count   53940.000000  53940.000000  53940  53940   53940  53940.000000
# unique           NaN           NaN      5      7       8           NaN
# top              NaN           NaN  Ideal      G     SI1           NaN
# freq             NaN           NaN  21551  11292   13065           NaN
# mean    26970.500000      0.797940    NaN    NaN     NaN     61.749405
# std     15571.281097      0.474011    NaN    NaN     NaN      1.432621
# min         1.000000      0.200000    NaN    NaN     NaN     43.000000
# 25%     13485.750000      0.400000    NaN    NaN     NaN     61.000000
# 50%     26970.500000      0.700000    NaN    NaN     NaN     61.800000
# 75%     40455.250000      1.040000    NaN    NaN     NaN     62.500000
# max     53940.000000      5.010000    NaN    NaN     NaN     79.000000
#
#                table         price             x             y             z
# ...

# %%
# Transpose for better readability
df.describe().T
# Out:
#             count          mean           std    min       25%       50%  \
# rownames  53940.0  26970.500000  15571.281097    1.0  13485.75  26970.50
# carat     53940.0      0.797940      0.474011    0.2      0.40      0.70
# depth     53940.0     61.749405      1.432621   43.0     61.00     61.80
# table     53940.0     57.457184      2.234491   43.0     56.00     57.00
# price     53940.0   3932.799722   3989.439738  326.0    950.00   2401.00
# x         53940.0      5.731157      1.121761    0.0      4.71      5.70
# y         53940.0      5.734526      1.142135    0.0      4.72      5.71
# z         53940.0      3.538734      0.705699    0.0      2.91      3.53
#
#                75%       max
# rownames  40455.25  53940.00
# carat         1.04      5.01
# depth        62.50     79.00
# table        59.00     95.00
# price      5324.25  18823.00
# x             6.54     10.74
# y             6.54     58.90
# z             4.04     31.80

# %%
# Custom percentiles
df.describe(percentiles=[.33, .66, .90])
# Out:
#            rownames         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 33%    17800.870000      0.500000     61.300000     56.000000   1228.000000
# 66%    35600.740000      1.000000     62.300000     58.000000   4221.000000
# 90%    48546.100000      1.510000     63.300000     60.000000   9821.000000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.to_csv('output.csv', index=False)

# %%
# Save to Excel
df.to_excel('output_index_false.xlsx', index=False)

df.to_excel('output_index_true.xlsx', index=True)

# %%
# Save to HTML
df.to_html('output.html')

# %%
# Save to JSON
df.head(10).to_json('output.json')

# Save the first 10 rows in a clean, human-readable JSON format
df.head(10).to_json('output_10.json', orient='records', indent=4)

# %%
# df = pd.read_csv('input.csv')

# Save to Excel
# df.to_excel('output.xlsx', index=False)

# %% [markdown]
# **Common Data Inspection Patterns**

# %%
# Step 1: Load the data
df = pd.read_json('output.json')

# Step 2: Quick overview
print(f"Dataset shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")

# Step 3: Examine first few rows
df.head()

# Step 4: Check data types and missing values
df.info()

# Step 5: Statistical summary
df.describe(include='all')

# Step 6: Check for duplicates
print(f"Duplicate rows: {df.duplicated().sum()}")
# Out:
# Dataset shape: (53940, 11)
# Columns: ['rownames', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y', 'z']
# <class 'pandas.DataFrame'>
# Index: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  53940 non-null  int64
#  1   carat     53940 non-null  float64
#  2   cut       53940 non-null  str
#  3   color     53940 non-null  str
#  4   clarity   53940 non-null  str
#  5   depth     53940 non-null  float64
#  6   table     53940 non-null  float64
#  7   price     53940 non-null  int64
#  8   x         53940 non-null  float64
#  9   y         53940 non-null  float64
#  10  z         53940 non-null  float64
# dtypes: float64(6), int64(2), str(3)
# memory usage: 4.9 MB
# Duplicate rows: 0

# %%
#Exercise 1
df = pd.read_csv('https://raw.githubusercontent.com/Md-Siam07/dataset/main/diamonds.csv')
df.head()
# Out:
#    rownames  carat      cut color clarity  depth  table  price     x     y  \
# 0         1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1         2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2         3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3         4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4         5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
#Exercise 2
(rows, columns) = df.shape
print(f'number of rows {rows}')
print(f'number of columns {columns}')
# Out:
# number of rows 53940
# number of columns 11

# %%
#Exercise 3
df.tail(7)
# Out:
#        rownames  carat        cut color clarity  depth  table  price     x  \
# 53933     53934   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69
# 53934     53935   0.72    Premium     D     SI1   62.7   59.0   2757  5.69
# 53935     53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936     53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937     53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938     53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939     53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53933  5.72  3.49
# 53934  5.73  3.58
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
#Exercise 4
print(f"Columns: {df.columns.tolist()}")
# Out:
# Columns: ['rownames', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y', 'z']

# %%
#Exercise 5
df.dtypes
# Out:
# rownames      int64
# carat       float64
# cut             str
# color           str
# clarity         str
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
#Exercise 6 & 7
df.describe(include='all')
# Out:
#             rownames         carat    cut  color clarity         depth  \
# count   53940.000000  53940.000000  53940  53940   53940  53940.000000
# unique           NaN           NaN      5      7       8           NaN
# top              NaN           NaN  Ideal      G     SI1           NaN
# freq             NaN           NaN  21551  11292   13065           NaN
# mean    26970.500000      0.797940    NaN    NaN     NaN     61.749405
# std     15571.281097      0.474011    NaN    NaN     NaN      1.432621
# min         1.000000      0.200000    NaN    NaN     NaN     43.000000
# 25%     13485.750000      0.400000    NaN    NaN     NaN     61.000000
# 50%     26970.500000      0.700000    NaN    NaN     NaN     61.800000
# 75%     40455.250000      1.040000    NaN    NaN     NaN     62.500000
# max     53940.000000      5.010000    NaN    NaN     NaN     79.000000
#
#                table         price             x             y             z
# ...
